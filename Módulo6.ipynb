# %% [markdown]
# # Módulo 6 - Aprendizado profundo
#
# Neste notebook, utilizaremos a biblioteca [Keras](https://www.keras.io) para construir uma rede neural do tipo Convolutional Neural Networks (CNN). Neste exemplo, iremos criar uma CNN para classificar imagens do dataset CIFAR-10. As imagens deste dataset são classificadas em 10 categorias. O objetivo é entender como este tipo de rede funciona. Ao final, você deverá realizar os exercícios propostos.
#
# Para começar, precisamos importar algumas bibliotecas.

# %%
import keras
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.callbacks import ModelCheckpoint
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Para utilizar o dataset CIFAR-10, basta executar o comando abaixo.  Este comando retorna duas tuplas, as quais representam os dados de treino (entrada e saída) e de teste (entrada e saída).

# %%
# carrega os conjuntos de treino e teste
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# Podemos visualizar alguns exemplos (de entrada e saída) do dataset utilizando o código abaixo.

# %%
cifar10_labels = ['avião', 'veículo', 'pássaro', 'gato', 'cervo', 'cachorro', 'sapo', 'cavalo', 'navio', 'caminhão']

fig = plt.figure(figsize=(20, 5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))
    ax.set_title("{}".format(cifar10_labels[y_train[i][0]]))

# %% [markdown]
# Após carregar os dados, devemos tratá-los para melhorar o treinamento. No nosso caso, vamos apenas normalizar as cores (atualmente no intervalo [0,255]) para o intervalo [0,1].

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# Em seguida, podemos codificar as classes utilizando o one-hot encoding. Isto vai facilitar o aprendizado.

# %%
# codificação one-hot das categorias
num_classes = len(np.unique(y_train))
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Outro passo importante é separar uma parte do conjunto de treino para validação. O objetivo é reduzir o bias do conjunto de teste.

# %%
# divide os dados em treino, teste e validação
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# %% [markdown]
# Após os tratamentos acima, podemos identificar o formato resultante dos nossos dados com os comandos abaixo.

# %%
# imprime o formato dos dados de entrada
print('Formato dos dados de entrada:', x_train.shape)

# imprime o tamanho dos conjuntos
print(x_train.shape[0], 'amostras de treino')
print(x_valid.shape[0], 'amostras de validação')
print(x_test.shape[0], 'amostras de teste')
# Out:
# Formato dos dados de entrada: (45000, 32, 32, 3)
# 45000 amostras de treino
# 5000 amostras de validação
# 10000 amostras de teste

# %% [markdown]
# Processados os dados, agora devemos criar a CNN. Como de costume, trabalharemos com um modelo sequencial.

# %%
model = Sequential()

# %% [markdown]
# Em seguida, podemos empilhar as camadas de convolução e agrupamento desejadas. Neste nosso caso, estamos trabalhando com 3 camadas convolucionais, cada qual com kernel de tamanho 2x2 e função de ativação ReLU. Após cada camada convolucional empilhamos uma camada de max pooling com kernel de tamanho 2x2.

# %%
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Lembre-se que as camadas convolucionais servem como um extrator de features, as quais serão utilizadas por um classificador MLP. Desta forma, agora precisamos converter a saída da parte convolucional para um vetor, que é o formato aceito por uma MLP. Isto pode ser feito com uma camada `Flatten`, como abaixo.

# %%
model.add(Flatten())

# %% [markdown]
# Finalmente, agora podemos adicionar as camadas densas de uma MLP para realizar a classificação. Note também que estamos utilizando Dropout para reduzir o overfitting.

# %%
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Nossa rede resultante é resumida abaixo.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 16)          │             208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 32)          │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 64)            │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │          51,250 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             510 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 62,304 (243.38 KB)
#  Trainable params: 62,304 (243.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# O próximo passo é compilar nosso modelo. Os parâmetros abaixo foram escolhidos por serem próprios para classificação.

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# Agora podemos finalmente treinar nosso modelo. **Cuidado, este processo pode demorar bastante!**  Para facilitar o estudo, reduzimos para apenas 10 épocas. Tente aumentar o número de épocas para ver entender melhor o efeito deste parâmetro nos resultados.
#
# Note que antes do treino, criamos um checkpoint. Um checkpoint permite que o modelo seja salvo em um arquivo. No nosso caso, apenas o melhor modelo será salvo. Desta forma, poderemos carregar nosso modelo posteriormente sem precisar treinar novamente a rede.

# %%
# Cria um checkpoint para salvar os pesos do melhor modelo encontrado no treinamento
checkpointer = ModelCheckpoint(filepath='model_weights_best.keras', verbose=1, save_best_only=True)

# Treina o modelo
hist = model.fit(
    x_train, y_train,
    batch_size=32,
    epochs=10,
    validation_data=(x_valid, y_valid),
    callbacks=[checkpointer],
    verbose=1,
    shuffle=True
)
# Out:
# Epoch 1/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2847 - loss: 1.9346
# Epoch 1: val_loss improved from inf to 1.48622, saving model to model_weights_best.keras
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.2848 - loss: 1.9345 - val_accuracy: 0.4790 - val_loss: 1.4862
# Epoch 2/10
# 1405/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4726 - loss: 1.4663
# Epoch 2: val_loss improved from 1.48622 to 1.33483, saving model to model_weights_best.keras
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.4726 - loss: 1.4662 - val_accuracy: 0.5148 - val_loss: 1.3348
# Epoch 3/10
# 1385/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5352 - loss: 1.3082
# Epoch 3: val_loss improved from 1.33483 to 1.21498, saving model to model_weights_best.keras
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5353 - loss: 1.3080 - val_accuracy: 0.5710 - val_loss: 1.2150
# Epoch 4/10
# 1392/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5752 - loss: 1.2184
# Epoch 4: val_loss improved from 1.21498 to 1.06683, saving model to model_weights_best.keras
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5752 - loss: 1.2183 - val_accuracy: 0.6140 - val_loss: 1.0668
# Epoch 5/10
# 1401/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5947 - loss: 1.1525
# Epoch 5: val_loss improved from 1.06683 to 1.05602, saving model to model_weights_best.keras
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5947 - loss: 1.1524 - val_accuracy: 0.6304 - val_loss: 1.0560
# Epoch 6/10
# 1390/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6166 - loss: 1.0959
# Epoch 6: val_loss did not improve from 1.05602
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6166 - loss: 1.0960 - val_accuracy: 0.6106 - val_loss: 1.1016
# Epoch 7/10
# 1403/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6236 - loss: 1.0690
# Epoch 7: val_loss did not improve from 1.05602
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6236 - loss: 1.0690 - val_accuracy: 0.6302 - val_loss: 1.1191
# Epoch 8/10
# 1391/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6351 - loss: 1.0451
# Epoch 8: val_loss improved from 1.05602 to 0.96004, saving model to model_weights_best.keras
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6352 - loss: 1.0451 - val_accuracy: 0.6702 - val_loss: 0.9600
# Epoch 9/10
# 1390/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 1.0273
# Epoch 9: val_loss did not improve from 0.96004
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6462 - loss: 1.0274 - val_accuracy: 0.6560 - val_loss: 1.0233
# Epoch 10/10
# 1384/1407 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6523 - loss: 1.0188
# Epoch 10: val_loss did not improve from 0.96004
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6522 - loss: 1.0188 - val_accuracy: 0.6690 - val_loss: 0.9608

# %% [markdown]
# Treinado o modelo, podemos analisar seu desempenho através dos gráficos abaixo.

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Como pode ser observado, nossa rede CNN conseguiu obter resultados bem interessantes mesmo sem uma otimização dos hiper-parâmetros.
#
# Após concluir o treino, podemos carregar o melhor modelo utilizando o comando abaixo.

# %%
# Carrega os pesos do melhor modelo encontrado no treinamento
model.load_weights('model_weights_best.keras')

# %% [markdown]
# A acurácia pode ser medida como segue.

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Acurácia:', score[1])
# Out:
#  Acurácia: 0.6650999784469604

# %% [markdown]
# Finalmente, podemos visualizar algumas predições do nosso modelo para entender melhor seu comportamento.

# %%
# obtém as predições
y_hat = model.predict(x_test)

# define os labels (fonte: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['avião', 'veículo', 'pássaro', 'gato', 'cervo', 'cachorro', 'sapo', 'cavalo', 'navio', 'caminhão']

# exibe alguns exemplos aleatórios do teste, bem como sua predição e o resultado esperado
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
#
# Ajuste a rede CNN vista acima para obter uma acurácia melhor no dataset CIFAR-10. Sua tarefa consiste em modificar a arquitetura da rede (e.g., quantidade de camadas, ordem das camadas, tamanho das camadas, loss function, otimizador, número de épocas, etc.).

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))

model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath='model.weights.best.keras', verbose=1, save_best_only=True)

hist = model.fit(
    x_train, y_train,
    batch_size=64,
    epochs=30,
    validation_data=(x_valid, y_valid),
    callbacks=[checkpointer],
    verbose=1,
    shuffle=True
)

score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Acurácia:', score[1])

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 550,570 (2.10 MB)
#  Trainable params: 550,570 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2227 - loss: 2.0453
# Epoch 1: val_loss improved from inf to 1.43221, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.2228 - loss: 2.0450 - val_accuracy: 0.4768 - val_loss: 1.4322
# Epoch 2/30
# 697/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4576 - loss: 1.4761
# Epoch 2: val_loss improved from 1.43221 to 1.21832, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4579 - loss: 1.4754 - val_accuracy: 0.5640 - val_loss: 1.2183
# Epoch 3/30
# 699/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5447 - loss: 1.2612
# Epoch 3: val_loss improved from 1.21832 to 1.04828, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5448 - loss: 1.2610 - val_accuracy: 0.6140 - val_loss: 1.0483
# Epoch 4/30
# 697/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5930 - loss: 1.1437
# Epoch 4: val_loss improved from 1.04828 to 0.94952, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5931 - loss: 1.1435 - val_accuracy: 0.6550 - val_loss: 0.9495
# Epoch 5/30
# 697/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6259 - loss: 1.0575
# Epoch 5: val_loss improved from 0.94952 to 0.88325, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6259 - loss: 1.0574 - val_accuracy: 0.6848 - val_loss: 0.8833
# Epoch 6/30
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6493 - loss: 0.9935
# Epoch 6: val_loss improved from 0.88325 to 0.84854, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6493 - loss: 0.9935 - val_accuracy: 0.6930 - val_loss: 0.8485
# Epoch 7/30
# 701/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6578 - loss: 0.9692
# Epoch 7: val_loss improved from 0.84854 to 0.81064, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.6578 - loss: 0.9691 - val_accuracy: 0.7126 - val_loss: 0.8106
# Epoch 8/30
# 701/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6822 - loss: 0.9101
# Epoch 8: val_loss did not improve from 0.81064
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.6822 - loss: 0.9101 - val_accuracy: 0.6996 - val_loss: 0.8327
# Epoch 9/30
# 699/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6845 - loss: 0.9026
# Epoch 9: val_loss improved from 0.81064 to 0.74309, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6846 - loss: 0.9025 - val_accuracy: 0.7364 - val_loss: 0.7431
# Epoch 10/30
# 700/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7029 - loss: 0.8467
# Epoch 10: val_loss did not improve from 0.74309
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7029 - loss: 0.8467 - val_accuracy: 0.7286 - val_loss: 0.7578
# Epoch 11/30
# 701/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7065 - loss: 0.8450
# Epoch 11: val_loss improved from 0.74309 to 0.72389, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7065 - loss: 0.8450 - val_accuracy: 0.7506 - val_loss: 0.7239
# Epoch 12/30
# 696/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7191 - loss: 0.8188
# Epoch 12: val_loss did not improve from 0.72389
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7191 - loss: 0.8188 - val_accuracy: 0.7388 - val_loss: 0.7349
# Epoch 13/30
# 697/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7245 - loss: 0.7913
# Epoch 13: val_loss improved from 0.72389 to 0.67182, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7245 - loss: 0.7914 - val_accuracy: 0.7650 - val_loss: 0.6718
# Epoch 14/30
# 702/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7274 - loss: 0.7860
# Epoch 14: val_loss did not improve from 0.67182
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7274 - loss: 0.7860 - val_accuracy: 0.7350 - val_loss: 0.7718
# Epoch 15/30
# 699/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7351 - loss: 0.7622
# Epoch 15: val_loss did not improve from 0.67182
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7351 - loss: 0.7622 - val_accuracy: 0.7584 - val_loss: 0.6864
# Epoch 16/30
# 696/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7428 - loss: 0.7501
# Epoch 16: val_loss improved from 0.67182 to 0.66947, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7428 - loss: 0.7501 - val_accuracy: 0.7632 - val_loss: 0.6695
# Epoch 17/30
# 699/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7465 - loss: 0.7300
# Epoch 17: val_loss improved from 0.66947 to 0.66441, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7464 - loss: 0.7301 - val_accuracy: 0.7714 - val_loss: 0.6644
# Epoch 18/30
# 702/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7435 - loss: 0.7342
# Epoch 18: val_loss improved from 0.66441 to 0.64181, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7435 - loss: 0.7342 - val_accuracy: 0.7784 - val_loss: 0.6418
# Epoch 19/30
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7527 - loss: 0.7151
# Epoch 19: val_loss did not improve from 0.64181
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7527 - loss: 0.7151 - val_accuracy: 0.7780 - val_loss: 0.6439
# Epoch 20/30
# 698/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7549 - loss: 0.7012
# Epoch 20: val_loss improved from 0.64181 to 0.59789, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7549 - loss: 0.7013 - val_accuracy: 0.7918 - val_loss: 0.5979
# Epoch 21/30
# 697/704 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7523 - loss: 0.7059
# Epoch 21: val_loss did not improve from 0.59789
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7524 - loss: 0.7059 - val_accuracy: 0.7966 - val_loss: 0.6075
# Epoch 22/30
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7605 - loss: 0.6974
# Epoch 22: val_loss did not improve from 0.59789
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7605 - loss: 0.6974 - val_accuracy: 0.7884 - val_loss: 0.6125
# Epoch 23/30
# 697/704 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7645 - loss: 0.6860
# Epoch 23: val_loss did not improve from 0.59789
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7644 - loss: 0.6861 - val_accuracy: 0.7912 - val_loss: 0.6043
# Epoch 24/30
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7689 - loss: 0.6752
# Epoch 24: val_loss improved from 0.59789 to 0.58285, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7689 - loss: 0.6752 - val_accuracy: 0.7996 - val_loss: 0.5828
# Epoch 25/30
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7657 - loss: 0.6809
# Epoch 25: val_loss did not improve from 0.58285
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7657 - loss: 0.6809 - val_accuracy: 0.7848 - val_loss: 0.6088
# Epoch 26/30
# 699/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7719 - loss: 0.6623
# Epoch 26: val_loss improved from 0.58285 to 0.57362, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7719 - loss: 0.6624 - val_accuracy: 0.8024 - val_loss: 0.5736
# Epoch 27/30
# 696/704 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7734 - loss: 0.6533
# Epoch 27: val_loss improved from 0.57362 to 0.57133, saving model to model.weights.best.keras
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7733 - loss: 0.6535 - val_accuracy: 0.8020 - val_loss: 0.5713
# Epoch 28/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7772 - loss: 0.6449
# Epoch 28: val_loss did not improve from 0.57133
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7772 - loss: 0.6449 - val_accuracy: 0.7834 - val_loss: 0.6462
# Epoch 29/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7775 - loss: 0.6371
# Epoch 29: val_loss did not improve from 0.57133
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7775 - loss: 0.6371 - val_accuracy: 0.7882 - val_loss: 0.6123
# Epoch 30/30
# 699/704 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7779 - loss: 0.6401
# Epoch 30: val_loss did not improve from 0.57133
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7779 - loss: 0.6401 - val_accuracy: 0.7956 - val_loss: 0.5887
#
#  Acurácia: 0.7853000164031982
